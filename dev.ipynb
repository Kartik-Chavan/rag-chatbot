# %%
from config.settings import ROOT_DIR , POLICY_DOCS_DIR
from llm.rag_chat_bot import ask_ai
from vectorstore.vectore_db import get_db
from rich import print
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from config.settings import ROOT_DIR , POLICY_DOCS_DIR
# ----> 2 from llm.rag_chat_bot import ask_ai
#       3 from vectorstore.vectore_db import get_db
#       4 from rich import print
#
# File c:\Drive F\Code\Project\Vinay_Project\llm\rag_chat_bot.py:8
#       6 from config.settings import DB_DIR
#       7 from langgraph.checkpoint.sqlite import SqliteSaver
# ----> 8 from vectorstore.retriever import get_context
#       9 from typing import TypedDict,Annotated,Sequence
#      10 from langchain_core.messages import BaseMessage , AIMessage,HumanMessage
#
# File c:\Drive F\Code\Project\Vinay_Project\vectorstore\retriever.py:4
#       2 from dotenv import load_dotenv
#       3 from langchain_cohere import CohereEmbeddings
# ----> 4 from vectorstore.vectore_db import get_db
# ...

# %%
user_input=""
res={}
while True:
    user_input=input("User : ")
    if user_input=="exit":
        break
    print("User : ",user_input)
    res = ask_ai(user_input,"2")
    print("AI : ",res)
# Out:
# User :  leave policy
# Context:  2
# 1.5
# Leave Policies
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 2
# 2
# Workplace Safety & Conduct
# 2
# 2.1
# Health & Safety Policy . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 3
# 2.2 , shift start via phone call. Excessive tardiness (3+ occurrences monthly) may trigger performance
# counseling.
# 1.5
# Leave Policies
# Full-time employees accrue PTO at the rate of 1.5 days per month (18 days annually), increasing , 2
# 1.3
# Compensation & Benefits . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 2
# 1.4
# Working Hours & Attendance . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 2
# 1.5
# Leave Policies ,
# AI :  Full-time employees accrue PTO at the rate of 1.5 days per month (18 days annually).
# User :  Can I use my personal phone for work under the BYOD policy?
# Context:  Bring Your Own Device (BYOD)
# ...

# %%
print(res)
# Out:
# Hello Jack! How can I assist you today?

# %%
from rich import print
with sqlite3.connect(DB_PATH) as conn:
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM sessions;")

    for row in cursor.fetchall():
        print(dict(row))
# Out:
# {
#     'id': 1,
#     'session_name': 'Chat a633ef15',
#     'thread_id': 'a633ef15-2ef9-458c-a0ea-1cb88dcf21e1',
#     'created_at': '2026-01-08 15:00:01'
# }
# {
#     'id': 2,
#     'session_name': 'Chat 733ecb93',
#     'thread_id': '733ecb93-8d44-4268-b1b7-bd6187f436ed',
#     'created_at': '2026-01-08 15:03:03'
# }

# %%
from langchain_community.vectorstores import Chroma

# %%
import os
from dotenv import load_dotenv
from langchain_cohere import CohereEmbeddings
from vectorstore.vectore_db import get_db
# Load environment variables
load_dotenv()



# Read API key securely
cohere_api_key = os.getenv("COHERE_API_KEY")

if not cohere_api_key:
    raise ValueError("COHERE_API_KEY not found in environment variables")
#Embedding Model Initialization
embeddings = CohereEmbeddings(
    model="embed-english-v3.0",  # Full model (not light) for HR policies
    cohere_api_key=cohere_api_key
)

db = get_db(embeddings=embeddings)
# Out:
# Loading existing vectorstore...

# %%
db.similarity_search(query="Leave policy")
# Out:
# [Document(id='2e0d1c2d-83ca-4ad7-8072-238417b09c47', metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-07T17:15:53+00:00', 'source': 'C:\\Drive F\\Code\\Project\\Vinay_Project\\data\\policy_documents\\Policy_Document.pdf', 'file_path': 'C:\\Drive F\\Code\\Project\\Vinay_Project\\data\\policy_documents\\Policy_Document.pdf', 'total_pages': 6, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-07T17:15:53+00:00', 'trapped': '', 'modDate': 'D:20260107171553Z', 'creationDate': 'D:20260107171553Z', 'page': 1}, page_content='2\n1.5\nLeave Policies\n. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n2\n2\nWorkplace Safety & Conduct\n2\n2.1\nHealth & Safety Policy . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n3\n2.2'),
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_cohere import ChatCohere
load_dotenv()



# Read API key securely
cohere_api_key = os.getenv("COHERE_API_KEY")

if not cohere_api_key:
    raise ValueError("COHERE_API_KEY not found in environment variables")

# Initialize LLM
llm = ChatCohere(cohere_api_key=cohere_api_key)

# %%
from rich import print
print("LLM Model Info: ", llm.invoke("Hi i am jack"))
# Out:
# LLM Model Info:
# AIMessage(
#     content="Hello Jack! It's nice to meet you. How can I assist you today? Whether you have questions, need help
# with a task, or just want to chat, I'm here for you.",
#     additional_kwargs={
#         'id': 'a08f02b2-91c0-4cf1-888e-da9aba8a029f',
#         'finish_reason': 'COMPLETE',
#         'content': "Hello Jack! It's nice to meet you. How can I assist you today? Whether you have questions, need
# help with a task, or just want to chat, I'm here for you.",
#         'token_count': {'input_tokens': 499.0, 'output_tokens': 42.0}
#     },
#     response_metadata={
#         'id': 'a08f02b2-91c0-4cf1-888e-da9aba8a029f',
#         'finish_reason': 'COMPLETE',
#         'content': "Hello Jack! It's nice to meet you. How can I assist you today? Whether you have questions, need
# help with a task, or just want to chat, I'm here for you.",
#         'token_count': {'input_tokens': 499.0, 'output_tokens': 42.0}
#     },
# ...

# %%
from pymongo import MongoClient
import os

client = MongoClient(os.getenv("MONGODB_URI"))
db = client[os.getenv("MONGODB_DB_NAME")]

print(db.list_collection_names())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[4], line 7
#       4 client = MongoClient(os.getenv("MONGODB_URI"))
#       5 db = client[os.getenv("MONGODB_DB_NAME")]
# ----> 7 print(db.list_collection_names())
#
# File c:\Drive F\Code\Project\Vinay_Project\menv\Lib\site-packages\pymongo\synchronous\database.py:1241, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1209 def list_collection_names(
#    1210     self,
#    1211     session: Optional[ClientSession] = None,
#    (...)   1214     **kwargs: Any,
#    1215 ) -> list[str]:
#    1216     """Get a list of all the collection names in this database.
#    1217
#    1218     For example, to list all non-system collections::
#    (...)   1239     .. versionadded:: 3.6
#    1240     """
# -> 1241     return self._list_collection_names(session, filter, comment, **kwargs)
#
# ...

# %%
import os

MONGODB_URI = os.getenv("MONGODB_URI")
MONGODB_DB_NAME = os.getenv("MONGODB_DB_NAME", "rag_chatbot_logs")

LOG_COLLECTION_CHAT = "chat_logs"
LOG_COLLECTION_POLICY = "policy_logs"
LOG_COLLECTION_ERROR = "error_logs"

# %%
from pymongo import MongoClient
from datetime import datetime

client = MongoClient(
    "mongodb+srv://rag-chatbot.21gkxy4.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509",
    tls=True,
    tlsCertificateKeyFile="./X509-cert-653997579436996077.pem",
    serverSelectionTimeoutMS=2000
)

db = client["rag_chatbot_logs"]

result = db["chat_logs"].insert_one({
    "test": "manual insert",
    "timestamp": datetime.utcnow()
})

print("Inserted ID:", result.inserted_id)
# Out:
# C:\Users\Kc925\AppData\Local\Temp\ipykernel_11280\1956471256.py:15: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow()
# Inserted ID: 696c8569bda82657370ff040

# %%
collection.insert_one({
    "msg": "X.509 auth test",
    "status": "success"
})

print(collection.count_documents({}))
# Out:
# 1

# %%
client.admin.command("ping")
print("MongoDB X.509 auth SUCCESS ✅")
# Out:
# MongoDB X.509 auth SUCCESS ✅
