# %%
from config.settings import ROOT_DIR , POLICY_DOCS_DIR
from llm.rag_chat_bot import ask_ai
from vectorstore.vectore_db import get_db
from rich import print
# Out:
# Loading existing vectorstore...

# %%
user_input=""
res={}
while True:
    user_input=input("User : ")
    if user_input=="exit":
        break
    print("User : ",user_input)
    res = ask_ai(user_input,"2")
    print("AI : ",res)
# Out:
# User :  hi i am kartik
# AI :  Hello Kartik! How can I assist you today?
# User :  i am employee in ABC corporation
# AI :  Hello Kartik! I'm here to assist you with any questions related to ABC Corporation's policies. How can I help
# you today?
# User :  what is leave policy
# AI :  The leave policy includes 18 days of Paid Time Off (PTO) accrual and 12 weeks of parental leave, with 8 weeks
# paid at 60% of your salary.
# User :  ok thank you
# AI :  You're welcome, Kartik! If you have any more questions about ABC Corporation's policies, feel free to ask.

# %%
print(res)
# Out:
# ABC Corporation's parental leave policy includes 12 weeks of leave, with 8 weeks paid at 60% of the employee's
# salary.
